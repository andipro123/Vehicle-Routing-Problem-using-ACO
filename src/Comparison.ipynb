# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('statistic_no_opt.csv')

# %%
#df.drop('Routes', inplace=True, axis=1)

# %%
#

# %%
plt.figure(figsize=(20,6))
plt.plot(df['Optimal'], label='Optimal')
plt.plot(df['Achieved'], label='Achieved')
plt.title('Solutions WITHOUT using Opt-2 technique')
plt.xlabel('Solution number')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
df = pd.read_csv('statistic_no_opt.csv')

# %%
df.drop('Routes', inplace=True, axis=1)

# %%
df
# Out:
#   File name  Number of Locations  Number of trucks  Capacity  Optimal  \
# 0  A-n32-k5                   32                 5       100      784
# 1  A-n33-k5                   33                 5       100      661
# 2  A-n33-k6                   33                 6       100      742
# 3  A-n34-k5                   34                 5       100      778
# 4  A-n36-k5                   36                 5       100      799
# 5  A-n37-k5                   37                 5       100      669
# 6  A-n37-k6                   37                 6       100      949
# 7  A-n38-k5                   38                 5       100      730
# 8  A-n39-k5                   39                 5       100      822
# 9  A-n39-k6                   39                 6       100      831
#
#    Achieved  2-opt  Work time
# 0   813.775   True     25.458
# 1   669.566   True     51.872
# 2   757.815   True     45.979
# 3   794.181   True     50.484
# 4   829.630   True     37.618
# ...

# %%
plt.figure(figsize=(20,6))
plt.plot(df['Optimal'], label='Optimal')
plt.plot(df['Achieved'], label='Achieved')
plt.title('Solutions WITH Opt-2 technique')
plt.xlabel('Solution number')
plt.ylabel('Value')
plt.legend()
plt.show()
